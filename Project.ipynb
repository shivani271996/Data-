# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pickle
import os
import math
# %matplotlib inline
# %matplotlib notebook

# %%
data = pd.read_csv("C:/Users/admin/Desktop/project data_analyst/country_data.csv")
data.tail(20)
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 136           137                     Egypt  4.166           0.913
# 137           138                    Zambia  4.107           0.578
# 138           139                      Togo  4.085           0.275
# 139           140                     India  4.015           0.755
# 140           141                   Liberia  3.975           0.073
# 141           142                   Comoros  3.973           0.274
# 142           143                Madagascar  3.933           0.274
# 143           144                   Lesotho  3.802           0.489
# 144           145                   Burundi  3.775           0.046
# 145           146                  Zimbabwe  3.663           0.366
# 146           147                     Haiti  3.597           0.323
# 147           148                  Botswana  3.488           1.041
# 148           149                     Syria  3.462           0.619
# ...

# %%
data.shape
# Out:
# (156, 9)

# %%
data.isna().sum()
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %%
print(np.info(data))
# Out:
# Two-dimensional, size-mutable, potentially heterogeneous tabular data.
#
# Data structure also contains labeled axes (rows and columns).
# Arithmetic operations align on both row and column labels. Can be
# thought of as a dict-like container for Series objects. The primary
# pandas data structure.
#
# Parameters
# ----------
# data : ndarray (structured or homogeneous), Iterable, dict, or DataFrame
#     Dict can contain Series, arrays, constants, or list-like objects.
#
#     .. versionchanged:: 0.23.0
#        If data is a dict, column order follows insertion-order for
#        Python 3.6 and later.
#
#     .. versionchanged:: 0.25.0
#        If data is a list of dicts, column order follows insertion-order
#        for Python 3.6 and later.
#
# index : Index or array-like
#     Index to use for resulting frame. Will default to RangeIndex if
#     no indexing information part of input data and no index provided.
# columns : Index or array-like
# ...

# %%
newdata=data.tail(20)
newdata
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 136           137                     Egypt  4.166           0.913
# 137           138                    Zambia  4.107           0.578
# 138           139                      Togo  4.085           0.275
# 139           140                     India  4.015           0.755
# 140           141                   Liberia  3.975           0.073
# 141           142                   Comoros  3.973           0.274
# 142           143                Madagascar  3.933           0.274
# 143           144                   Lesotho  3.802           0.489
# 144           145                   Burundi  3.775           0.046
# 145           146                  Zimbabwe  3.663           0.366
# 146           147                     Haiti  3.597           0.323
# 147           148                  Botswana  3.488           1.041
# 148           149                     Syria  3.462           0.619
# ...

# %%
newdata["Social support"].sum()
# Out:
# 15.380999999999998

# %%
newdata.plot.bar(y="Overall rank",x="Score")
# Out:
# <img src="data:image/png;base64,..." width="432">
# <AxesSubplot:xlabel='Score'>

# %%
newdata.plot.bar(y=["Freedom to make life choices","Generosity"], x="Score")
# Out:
# <img src="data:image/png;base64,..." width="432">
# <AxesSubplot:xlabel='Score'>

# %%
newdata.plot.bar(y=["Freedom to make life choices","Generosity","Healthy life expectancy","Perceptions of corruption"], x="Score", subplots=True, layout=(2,2))
# Out:
# <img src="data:image/png;base64,..." width="432">
# array([[<AxesSubplot:title={'center':'Freedom to make life choices'}, xlabel='Score'>,
#         <AxesSubplot:title={'center':'Generosity'}, xlabel='Score'>],
#        [<AxesSubplot:title={'center':'Healthy life expectancy'}, xlabel='Score'>,
#         <AxesSubplot:title={'center':'Perceptions of corruption'}, xlabel='Score'>]],
#       dtype=object)

# %%
newdata.plot(y=["Freedom to make life choices","Generosity","Healthy life expectancy","Perceptions of corruption"], x="Score", subplots=True, layout=(2,2))
# Out:
# <img src="data:image/png;base64,..." width="432">
# array([[<AxesSubplot:xlabel='Score'>, <AxesSubplot:xlabel='Score'>],
#        [<AxesSubplot:xlabel='Score'>, <AxesSubplot:xlabel='Score'>]],
#       dtype=object)

# %%
newdata.plot.scatter(x="Score",y="Overall rank")
# Out:
# <img src="data:image/png;base64,..." width="432">
# <AxesSubplot:xlabel='Score', ylabel='Overall rank'>

# %%
newdata.plot.pie(y="Score",x="Overall rank")
# Out:
# <img src="data:image/png;base64,..." width="432">
# <AxesSubplot:ylabel='Score'>

# %%
newdata.apply(lambda x:sum(x.isnull()),axis=0)
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %%
newdata["Country or region"].unique()
# Out:
# array(['Egypt', 'Zambia', 'Togo', 'India', 'Liberia', 'Comoros',
#        'Madagascar', 'Lesotho', 'Burundi', 'Zimbabwe', 'Haiti',
#        'Botswana', 'Syria', 'Malawi', 'Yemen', 'Rwanda', 'Tanzania',
#        'Afghanistan', 'Central African Republic', 'South Sudan'],
#       dtype=object)

# %%
newdata.describe()
# Out:
#        Overall rank      Score  GDP per capita  Social support  \
# count      20.00000  20.000000       20.000000       20.000000
# mean      146.50000   3.626750        0.401050        0.769050
# std         5.91608   0.379924        0.270423        0.310532
# min       137.00000   2.853000        0.026000        0.000000
# 25%       141.75000   3.368500        0.274000        0.569000
# 50%       146.50000   3.630000        0.336500        0.761000
# 75%       151.25000   3.973500        0.511250        1.043750
# max       156.00000   4.166000        1.041000        1.169000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count                20.000000                     20.000000    20.00000
# mean                  0.440550                      0.267500     0.20000
# std                   0.134983                      0.176269     0.08915
# min                   0.105000                      0.000000     0.02500
# ...

# %%
newdata.dtypes
# Out:
# Overall rank                      int64
# Country or region                object
# Score                           float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# dtype: object

# %%
sns.boxplot(x=newdata["Social support"])
# Out:
# <AxesSubplot:xlabel='Social support', ylabel='Score'>

# %%
newdata[1:6]
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 137           138            Zambia  4.107           0.578           1.058
# 138           139              Togo  4.085           0.275           0.572
# 139           140             India  4.015           0.755           0.765
# 140           141           Liberia  3.975           0.073           0.922
# 141           142           Comoros  3.973           0.274           0.757
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 137                    0.426                         0.431       0.247
# 138                    0.410                         0.293       0.177
# 139                    0.588                         0.498       0.200
# 140                    0.443                         0.370       0.233
# 141                    0.505                         0.142       0.275
#
#      Perceptions of corruption
# 137                      0.087
# ...
